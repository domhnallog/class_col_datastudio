# %%
import csv
import pandas as pd
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
import seaborn as sns
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
# %matplotlib inline

# %%
timecard_df = pd.read_excel('sources/TimeCard.xls')
timecard_df
# Out:
#     Time Sheet Audit for Date Range from 07/01/2017 to 02/21/2018  \
# 0                                              By User
# 1                         Employee: Doe, Jane (214365)
# 2                         Employee: Doe, Jane (214365)
# 3                         Employee: Doe, Jane (214365)
# 4                         Employee: Doe, Jane (214365)
# ..                                                 ...
# 390                       Employee: Doe, Jane (214365)
# 391                       Employee: Doe, Jane (214365)
# 392                       Employee: Doe, Jane (214365)
# 393                       Employee: Doe, Jane (214365)
# 394                       Employee: Doe, Jane (214365)
#
#               Unnamed: 1           Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0             Changed on            Work Date    In Time   Out Time
# 1    2017-07-21 12:20:00  2017-07-17 00:00:00   08:00:00   17:00:00
# 2    2017-07-21 12:21:00  2017-07-17 00:00:00   08:15:00   17:00:00
# ...
